# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-extended-missing-data.csv
# Out:
# --2025-05-02 14:47:34--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-extended-missing-data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 30921 (30K) [text/plain]
# Saving to: ‘car-sales-extended-missing-data.csv’
#
# car-sales-extended- 100%[===================>]  30.20K  --.-KB/s    in 0.01s
#
# 2025-05-02 14:47:34 (2.89 MB/s) - ‘car-sales-extended-missing-data.csv’ saved [30921/30921]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/car-sales-extended-missing-data.csv')

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  950 non-null    float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
df.describe()
# Out:
#        Odometer (KM)       Doors         Price
# count     950.000000  950.000000    950.000000
# mean   131253.237895    4.011579  16042.814737
# std     69094.857187    0.382539   8581.695036
# min     10148.000000    3.000000   2796.000000
# 25%     70391.250000    4.000000   9529.250000
# 50%    131821.000000    4.000000  14297.000000
# 75%    192668.500000    4.000000  20806.250000
# max    249860.000000    5.000000  52458.000000

# %%
X = df.drop('Price', axis=1)
y = df['Price'].copy()

# %%
# regression
df.isna().sum()
# Out:
# Make             49
# Colour           50
# Odometer (KM)    50
# Doors            50
# Price            50
# dtype: int64

# %%
df.dropna(subset='Price', inplace=True)

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
df.isna().sum()
# Out:
# Make             47
# Colour           46
# Odometer (KM)    48
# Doors            47
# Price             0
# dtype: int64

# %%
X = df.drop('Price', axis=1)
y = df['Price'].copy()

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train
# Out:
#        Make Colour  Odometer (KM)  Doors
# 162   Honda  White       100527.0    4.0
# 476  Toyota  White       185742.0    4.0
# 652     NaN  White        19482.0    3.0
# 919   Honda  Black       231659.0    4.0
# 185  Nissan    Red       191810.0    3.0
# ..      ...    ...            ...    ...
# 339  Toyota    Red        65435.0    4.0
# 500   Honda  Black       221461.0    4.0
# 856  Toyota    NaN        51788.0    4.0
# 130  Nissan    NaN        18994.0    4.0
# 75   Toyota   Blue       156478.0    NaN
#
# [760 rows x 4 columns]

# %%
y_train
# Out:
# 162    22616.0
# 476    16865.0
# 652    31208.0
# 919     9826.0
# 185    14189.0
#         ...
# 339    24949.0
# 500    10450.0
# 856     6480.0
# 130     7813.0
# 75     20424.0
# Name: Price, Length: 760, dtype: float64

# %%
# w1 * Make + w2 * Colour + w3 * Odometer + w4 * Doors + b = y     wx + b = y

# %%
# LabelEncoder OrdinalEncoder OneHotEncoder

# %%
X['Doors'].fillna(X['Doors'].median()) # Replaces NaN with the median
# Out:
# 0      4.0
# 1      5.0
# 2      4.0
# 3      4.0
# 4      3.0
#       ...
# 995    4.0
# 996    3.0
# 997    4.0
# 998    4.0
# 999    4.0
# Name: Doors, Length: 950, dtype: float64

# %%
X['Make'].fillna(value='Missing').value_counts()
# Out:
# Make
# Toyota     354
# Honda      281
# Nissan     175
# BMW         93
# Missing     47
# Name: count, dtype: int64

# %%
X['Make'] = X['Make'].fillna(X['Make'].mode()[0])

# %%
X['Make'].mode()
# Out:
# 0    Toyota
# Name: Make, dtype: object

# %%
X['Colour'] = X['Colour'].fillna(X['Colour'].mode()[0])

# %%
X['Colour'].mode()
# Out:
# 0    White
# Name: Colour, dtype: object

# %%
X.isna().sum()
# Out:
# Make              0
# Colour            0
# Odometer (KM)    48
# Doors            47
# dtype: int64

# %%
X.Make.value_counts()
# Out:
# Make
# Toyota    401
# Honda     281
# Nissan    175
# BMW        93
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
ordinal_enc = OrdinalEncoder()

# %%
X_train['Make'] = X_train['Make'].fillna('Missing')
X_test['Make'] = X_test['Make'].fillna('Missing')
X_train['Colour'] = X_train['Colour'].fillna('Missing')
X_test['Colour'] = X_test['Colour'].fillna('Missing')
X_train['Odometer (KM)'] = X_train['Odometer (KM)'].fillna(X_train['Odometer (KM)'].median())
X_test['Odometer (KM)'] = X_test['Odometer (KM)'].fillna(X_train['Odometer (KM)'].median())
X_train['Doors'] = X_train['Doors'].fillna(X_train['Doors'].median())
X_test['Doors'] = X_test['Doors'].fillna(X_train['Doors'].median())

# %%
X_train['Make'] = ordinal_enc.fit_transform(pd.DataFrame(X_train['Make']))
X_test['Make'] = ordinal_enc.transform(pd.DataFrame(X_test['Make']))
X_train['Colour'] = ordinal_enc.fit_transform(pd.DataFrame(X_train['Colour']))
X_test['Colour'] = ordinal_enc.transform(pd.DataFrame(X_test['Colour']))

# %%
X['Make_encoded'] = ordinal_enc.fit_transform(pd.DataFrame(X['Make']))

# %%
X
# Out:
#        Make Colour  Odometer (KM)  Doors  Make_encoded
# 0     Honda  White        35431.0    4.0           1.0
# 1       BMW   Blue       192714.0    5.0           0.0
# 2     Honda  White        84714.0    4.0           1.0
# 3    Toyota  White       154365.0    4.0           3.0
# 4    Nissan   Blue       181577.0    3.0           2.0
# ..      ...    ...            ...    ...           ...
# 995  Toyota  Black        35820.0    4.0           3.0
# 996  Toyota  White       155144.0    3.0           3.0
# 997  Nissan   Blue        66604.0    4.0           2.0
# 998   Honda  White       215883.0    4.0           1.0
# 999  Toyota   Blue       248360.0    4.0           3.0
#
# [950 rows x 5 columns]

# %%
X['Colour_encoded'] = ordinal_enc.fit_transform(pd.DataFrame(X['Colour']))

# %%
X
# Out:
#        Make Colour  Odometer (KM)  Doors  Make_encoded  Colour_encoded
# 0     Honda  White        35431.0    4.0           1.0             4.0
# 1       BMW   Blue       192714.0    5.0           0.0             1.0
# 2     Honda  White        84714.0    4.0           1.0             4.0
# 3    Toyota  White       154365.0    4.0           3.0             4.0
# 4    Nissan   Blue       181577.0    3.0           2.0             1.0
# ..      ...    ...            ...    ...           ...             ...
# 995  Toyota  Black        35820.0    4.0           3.0             0.0
# 996  Toyota  White       155144.0    3.0           3.0             4.0
# 997  Nissan   Blue        66604.0    4.0           2.0             1.0
# 998   Honda  White       215883.0    4.0           1.0             4.0
# 999  Toyota   Blue       248360.0    4.0           3.0             1.0
#
# [950 rows x 6 columns]

# %%
X.drop(['Make', 'Colour'], axis=1, inplace=True)

# %%
X
# Out:
#      Odometer (KM)  Doors  Make_encoded  Colour_encoded
# 0          35431.0    4.0           1.0             4.0
# 1         192714.0    5.0           0.0             1.0
# 2          84714.0    4.0           1.0             4.0
# 3         154365.0    4.0           3.0             4.0
# 4         181577.0    3.0           2.0             1.0
# ..             ...    ...           ...             ...
# 995        35820.0    4.0           3.0             0.0
# 996       155144.0    3.0           3.0             4.0
# 997        66604.0    4.0           2.0             1.0
# 998       215883.0    4.0           1.0             4.0
# 999       248360.0    4.0           3.0             1.0
#
# [950 rows x 4 columns]

# %%
X
# Out:
#      Odometer (KM)  Doors  Make_encoded  Colour_encoded
# 0          35431.0    4.0           1.0             4.0
# 1         192714.0    5.0           0.0             1.0
# 2          84714.0    4.0           1.0             4.0
# 3         154365.0    4.0           3.0             4.0
# 4         181577.0    3.0           2.0             1.0
# ..             ...    ...           ...             ...
# 995        35820.0    4.0           3.0             0.0
# 996       155144.0    3.0           3.0             4.0
# 997        66604.0    4.0           2.0             1.0
# 998       215883.0    4.0           1.0             4.0
# 999       248360.0    4.0           3.0             1.0
#
# [950 rows x 4 columns]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(X, y)
# Out:
# RandomForestRegressor()

# %%
rfr.score(X, y)
# Out:
# 0.8704700185505008

# %%
df
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [950 rows x 5 columns]

# %%
X_train.isna().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor()

# %%
rfr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
rfr.score(X_train, y_train)
# Out:
# 0.8648776775446224

# %%
rfr.score(X_test, y_test)
# Out:
# 0.292436367129175

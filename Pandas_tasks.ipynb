# %%
import pandas as pd

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/pandas-exercises.ipynb
# Out:
# --2025-07-22 11:41:46--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/pandas-exercises.ipynb
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14082 (14K) [text/plain]
# Saving to: ‘pandas-exercises.ipynb’
#
# pandas-exercises.ip 100%[===================>]  13.75K  --.-KB/s    in 0.001s
#
# 2025-07-22 11:41:46 (17.1 MB/s) - ‘pandas-exercises.ipynb’ saved [14082/14082]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks"
# Out:
# 'airline passenger .ipynb'
#  Azer_GDP.ipynb
# 'Bank Customer Churn.ipynb'
# 'Bank Marketing Dataset.ipynb'
# 'Bank Marketing.ipynb'
#  Car_sales.ipynb
# 'case project by Elvin Shirinov (1).ipynb'
#  Churn_Analysis_with_clustering.ipynb
#  Classificatin_part1.ipynb
#  Clustering.ipynb
#  data_analitycs.ipynb
# 'Deep Learning.ipynb'
#  Desicions_Trees.ipynb
#  Desicion_tree_algorithms.ipynb
# 'Diabetes Health Indicators Dataset .ipynb'
#  Diabetes_prediction_dataset.ipynb
#  Diabetes_Prediction.ipynb
#  Dict_Init.ipynb
#  Dictionary_Demo.ipynb
#  dimensionality_reduction.ipynb
#  Ensemble_Learning.ipynb
#  Exam_turbo.ipynb
#  False_variables.ipynb
#  Fashion-Mnist.ipynb
# 'Fruits and Vegetables Image Recognition Dataset.ipynb'
# 'Global_Terrorism .ipynb'
#  housing_prices.ipynb
# 'HyperParameter Tuning.ipynb'
#  introduction_to_ComputerVision.ipynb
# 'Introduction to Computer Vision with Tensorflow.ipynb'
# 'Laptop Prices.ipynb'
#  Last_lessonipynb
# ...

# %%
df = pd.read_excel('/content/INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8 (3).xlsx')
df
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
df[['Age','DistanceFromHome']][:5]
# Out:
#    Age  DistanceFromHome
# 0   32                10
# 1   47                14
# 2   40                 5
# 3   41                10
# 4   60                16

# %%
df[df['DistanceFromHome']==df['DistanceFromHome'].max()]
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 62    E1001114   42    Male       Life Sciences       Married
# 177   E1001315   26    Male             Medical        Single
# 184   E1001324   32  Female             Medical        Single
# 212   E1001379   33  Female             Medical        Single
# 239   E1001426   42    Male             Medical        Single
# 275   E1001489   30    Male       Life Sciences      Divorced
# 283   E1001503   44    Male               Other        Single
# 364   E1001655   34    Male             Medical       Married
# 410   E1001743   45    Male    Technical Degree       Married
# 440   E1001792   28    Male       Life Sciences       Married
# 469   E1001846   30    Male    Technical Degree       Married
# 561   E1002003   24    Male             Medical      Divorced
# 599   E1002062   31  Female           Marketing       Married
# 636   E1002137   29    Male       Life Sciences      Divorced
# ...

# %%
df['Gender'][df['DistanceFromHome']==df['DistanceFromHome'].max()]
# Out:
# 62        Male
# 177       Male
# 184     Female
# 212     Female
# 239       Male
# 275       Male
# 283       Male
# 364       Male
# 410       Male
# 440       Male
# 469       Male
# 561       Male
# 599     Female
# 636       Male
# 726     Female
# 733       Male
# 815     Female
# 880       Male
# 930       Male
# 935       Male
# 1102    Female
# 1116      Male
# 1117      Male
# Name: Gender, dtype: object

# %%
df[df['Age'] == 40]
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 2     E1001007   40    Male       Life Sciences       Married
# 18    E1001041   40  Female             Medical        Single
# 44    E1001085   40  Female             Medical       Married
# 59    E1001110   40    Male             Medical        Single
# 141   E1001264   40  Female       Life Sciences        Single
# 194   E1001344   40    Male           Marketing       Married
# 208   E1001370   40    Male    Technical Degree       Married
# 230   E1001406   40    Male             Medical        Single
# 251   E1001444   40  Female             Medical        Single
# 258   E1001458   40  Female             Medical       Married
# 276   E1001490   40    Male             Medical       Married
# 337   E1001596   40    Male           Marketing        Single
# 343   E1001618   40    Male       Life Sciences      Divorced
# 352   E1001639   40    Male       Life Sciences       Married
# ...

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female': 0})
df['Gender'].astype(int)
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1195    0
# 1196    1
# 1197    1
# 1198    0
# 1199    0
# Name: Gender, Length: 1200, dtype: int64

# %%
df.groupby('Gender').mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-3774296011> in <cell line: 0>()
# ----> 1 df.groupby('Gender').mean()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# -> 1329             grouper, exclusions, obj = get_grouper(
#    1330                 obj,
#    1331                 keys,
#
# ...

# %%
# Create a series of three different colours
# View the series of different colours
colors = pd.Series(['red', 'green', 'blue'])
print(colors)
# Out:
# 0      red
# 1    green
# 2     blue
# dtype: object

# %%
# Create a series of three different car types and view it
cars = pd.Series(['Toyota', 'Honda', 'Ford'])
print(cars)
# Out:
# 0    Toyota
# 1     Honda
# 2      Ford
# dtype: object

# %%
cars.str.upper()
cars[0]
# Out:
# 'Toyota'

# %%
# Combine the Series of cars and colours into a DataFrame
df = pd.DataFrame({'Colors': colors, 'Cars': cars})
print(df)
# Out:
#   Colors    Cars
# 0    red  Toyota
# 1  green   Honda
# 2   blue    Ford

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2025-06-11 14:44:50--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv’
#
# car-sales.csv       100%[===================>]     369  --.-KB/s    in 0s
#
# 2025-06-11 14:44:50 (4.53 MB/s) - ‘car-sales.csv’ saved [369/369]

# %%
# Import "../data/car-sales.csv" and turn it into a DataFrame
df = pd.read_csv('/content/car-sales.csv')
print(df)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Export the DataFrame you created to a .csv file
df.to_csv('my_colors.csv', index=False)

# %%
df_read = pd.read_csv('my_colors.csv')
print(df_read)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# Find the different datatypes of the car data DataFrame
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
# Describe your current car sales DataFrame using describe()
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
# Get information about your DataFrame using info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
# Create a Series of different numbers and find the mean of them
numbers = pd.Series([1, 2, 3, 4, 5])
numbers.mean()
# Out:
# np.float64(3.0)

# %%
# Create a Series of different numbers and find the sum of them
numbers = pd.Series([1, 2, 3, 4, 5])
numbers.sum()
# Out:
# np.int64(15)

# %%
# List out all the column names of the car sales DataFrame
df.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
# Find the length of the car sales DataFrame
len(df)
# Out:
# 10

# %%
# Show the first 5 rows of the car sales DataFrame
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
df.tail()
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 1195   E100992   27       0             Medical      Divorced         Sales
# 1196   E100993   37       1       Life Sciences        Single   Development
# 1197   E100994   50       1             Medical       Married   Development
# 1198   E100995   34       0             Medical        Single  Data Science
# 1199   E100998   24       0       Life Sciences        Single         Sales
#
#             EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 1195   Sales Executive       Travel_Frequently                 3
# 1196  Senior Developer           Travel_Rarely                10
# 1197  Senior Developer           Travel_Rarely                28
# 1198    Data Scientist           Travel_Rarely                 9
# 1199   Sales Executive           Travel_Rarely                 3
#
#       EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# ...

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
df.loc[3]
# Out:
# EmpNumber                              E1001009
# Age                                          41
# Gender                                        1
# EducationBackground             Human Resources
# MaritalStatus                          Divorced
# EmpDepartment                   Human Resources
# EmpJobRole                              Manager
# BusinessTravelFrequency           Travel_Rarely
# DistanceFromHome                             10
# EmpEducationLevel                             4
# EmpEnvironmentSatisfaction                    2
# EmpHourlyRate                                73
# EmpJobInvolvement                             2
# EmpJobLevel                                   5
# EmpJobSatisfaction                            4
# NumCompaniesWorked                            3
# OverTime                                     No
# EmpLastSalaryHikePercent                     15
# EmpRelationshipSatisfaction                   2
# TotalWorkExperienceInYears                   23
# ...

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
# print(df['Odometer (KM)'])
df['Odometer (KM)']
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
print(df['Odometer (KM)'].mean())
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
df[df['Odometer (KM)'] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(df['Make'], df['Doors'])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
df.groupby('Make')['Doors'].mean()
# Out:
# Make
# BMW       5.00
# Honda     4.00
# Nissan    4.00
# Toyota    3.75
# Name: Doors, dtype: float64

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
# %matplotlib inline
import matplotlib.pyplot as plt
plt.hist('Odometer (KM)')
plt.show()

# %%
# Create a histogram of the Odometer column using hist()
df['Odometer (KM)'].hist()
plt.title('Histogram of Odometer Column')
plt.show()

# %%
# Remove dollar signs and commas from the Price column
df['Price'] = df['Price'].replace({'\$': '', ',': ''}, regex=True)

# Convert the cleaned Price column to numeric and divide by 100
df['Price'] = pd.to_numeric(df['Price']) / 100

# Check the dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Odometer (KM)  10 non-null     int64
#  1   Doors          10 non-null     int64
#  2   Price          10 non-null     float64
# dtypes: float64(1), int64(2)
# memory usage: 372.0 bytes

# %%
df['Price'].sum()
# Out:
# np.float64(764.5)

# %%
df['Odometer per Doors'] = df['Odometer (KM)'] / df['Doors']
df
# Out:
#    Odometer (KM)  Doors  Price  Odometer per Doors
# 0         150043      4   40.0        37510.750000
# 1          87899      4   50.0        21974.750000
# 2          32549      3   70.0        10849.666667
# 3          11179      5  220.0         2235.800000
# 4         213095      4   35.0        53273.750000
# 5          99213      4   45.0        24803.250000
# 6          45698      4   75.0        11424.500000
# 7          54738      4   70.0        13684.500000
# 8          60000      4   62.5        15000.000000
# 9          31600      4   97.0         7900.000000

# %%
# Try to plot the Price column using plot()
df['Price'].plot()
# Out:
# <Axes: >

# %%
# Remove the punctuation from price column
df['Price'] = df['Price'].replace({'\$': '', ',': ''}, regex=True)

# %%
# Check the changes to the price column
df['Price']
# Out:
# 0     40.0
# 1     50.0
# 2     70.0
# 3    220.0
# 4     35.0
# 5     45.0
# 6     75.0
# 7     70.0
# 8     62.5
# 9     97.0
# Name: Price, dtype: float64

# %%
# Remove the two extra zeros at the end of the price column
df['Price']=df['Price'].astype(float) / 100

# %%
# Check the changes to the Price column
df['Price']
# Out:
# 0    0.400
# 1    0.500
# 2    0.700
# 3    2.200
# 4    0.350
# 5    0.450
# 6    0.750
# 7    0.700
# 8    0.625
# 9    0.970
# Name: Price, dtype: float64

# %%
# Change the datatype of the Price column to integers
df['Price'] = df['Price'].replace({'\$': '', ',': ''}, regex=True).astype(float)

avg_by_make_column = df.groupby('Make')['Price'].mean()
avg_by_make_column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-82-937651890> in <cell line: 0>()
#       2 df['Price'] = df['Price'].replace({'\$': '', ',': ''}, regex=True).astype(float)
#       3
# ----> 4 avg_by_make_column = df.groupby('Make')['Price'].mean()
#       5 avg_by_make_column
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9181             raise TypeError("You have to supply one of 'by' and 'level'")
#    9182
# -> 9183         return DataFrameGroupBy(
#    9184             obj=self,
#    9185             keys=by,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1327
#    1328         if grouper is None:
# ...

# %%
df.shape
# Out:
# (10, 6)

# %%
df[df['Odometer (KM)'] < 50000]
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Odometer per Doors
# 2  Toyota   Blue          32549      3   0.70        10849.666667
# 3     BMW  Black          11179      5   2.20         2235.800000
# 6   Honda   Blue          45698      4   0.75        11424.500000
# 9  Nissan  White          31600      4   0.97         7900.000000

# %%
df[df['Colour'] == 'Blue']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Colour'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-81-2103738155> in <cell line: 0>()
# ----> 1 df[df['Colour'] == 'Blue']
#
# ...

# %%
df['Odometer (KM)'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Odometer (KM)'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Price'] = df['Price'].astype(str)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3724979124> in <cell line: 0>()
# ----> 1 df['Price'] = df['Price'].astype(str)
#       2 df
#
# NameError: name 'df' is not defined

# %%
df['Price'] = df['Price'].astype(str).str.rstrip('0').str.rstrip('.')
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Odometer per Doors
# 0  Toyota  White         150043      4    0.4        37510.750000
# 1   Honda    Red          87899      4    0.5        21974.750000
# 2  Toyota   Blue          32549      3    0.7        10849.666667
# 3     BMW  Black          11179      5    2.2         2235.800000
# 4  Nissan  White         213095      4   0.35        53273.750000
# 5  Toyota  Green          99213      4   0.45        24803.250000
# 6   Honda   Blue          45698      4   0.75        11424.500000
# 7   Honda   Blue          54738      4    0.7        13684.500000
# 8  Toyota  White          60000      4  0.625        15000.000000
# 9  Nissan  White          31600      4   0.97         7900.000000

# %%
# Lower the strings of the Make column
df['Make'] = df['Make'].str.lower()
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Make'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-86-2251700495> in <cell line: 0>()
#       1 # Lower the strings of the Make column
# ...

# %%
df_odometer_series = df['Odometer (KM)']
df_odometer_series
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
mean_of_odometer_column = df['Odometer (KM)'].mean()
mean_of_odometer_column
# Out:
# np.float64(78601.4)

# %%
select_more_than_100000_km = df[df['Odometer (KM)'] > 100000]
select_more_than_100000_km
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
df_cross_tab = pd.crosstab(df['Make'], df['Doors'])
df_cross_tab
# Out:
# Doors   3  4  5
# Make
# bmw     0  0  1
# honda   0  3  0
# nissan  0  2  0
# toyota  1  3  0

# %%
len(df)
# Out:
# 10

# %%
df.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors Price  Odometer per Doors
# 0  toyota  White         150043      4   0.4        37510.750000
# 1   honda    Red          87899      4   0.5        21974.750000
# 2  toyota   Blue          32549      3   0.7        10849.666667
# 3     bmw  Black          11179      5   2.2         2235.800000
# 4  nissan  White         213095      4  0.35        53273.750000

# %%
sum_of_number_series = pd.Series([1, 2, 3, 4, 5, 6, 7, 8]).sum()
sum_of_number_series
# Out:
# np.int64(36)

# %%
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price',
#        'Odometer per Doors'],
#       dtype='object')

# %%
df_missing = pd.read_csv('https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv')
df_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Make lowering the case of the Make column permanent
df_missing['Make'] = df_missing['Make'].str.lower()
df_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  toyota  White  150043.0    4.0   $4,000
# 1   honda    Red   87899.0    4.0   $5,000
# 2  toyota   Blue       NaN    3.0   $7,000
# 3     bmw  Black   11179.0    5.0  $22,000
# 4  nissan  White  213095.0    4.0   $3,500
# 5  toyota  Green       NaN    4.0   $4,500
# 6   honda    NaN       NaN    4.0   $7,500
# 7   honda   Blue       NaN    4.0      NaN
# 8  toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# remove the missing values of column, Make
df_missing = df_missing.dropna(subset=['Make'])

# %%
df_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-60-2327262285> in <cell line: 0>()
# ----> 1 df_missing
#
# NameError: name 'df_missing' is not defined

# %%
# remove the missing values of column, Colour
df_missing = df_missing.dropna(subset=['Colour'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-1636620679> in <cell line: 0>()
#       1 # remove the missing values of column, Colour
# ----> 2 df_missing = df_missing.dropna(subset=['Colour'])
#
# NameError: name 'df_missing' is not defined

# %%
# Check the car sales DataFrame
df_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  toyota  White  150043.0    4.0   $4,000
# 1   honda    Red   87899.0    4.0   $5,000
# 2  toyota   Blue       NaN    3.0   $7,000
# 3     bmw  Black   11179.0    5.0  $22,000
# 4  nissan  White  213095.0    4.0   $3,500
# 5  toyota  Green       NaN    4.0   $4,500
# 7   honda   Blue       NaN    4.0      NaN
# 8  toyota  White   60000.0    NaN      NaN

# %%
# remove the missing values of column, Doors
df_missing = df_missing.dropna(subset=['Doors'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-151050844> in <cell line: 0>()
#       1 # remove the missing values of column, Doors
# ----> 2 df_missing = df_missing.dropna(subset=['Doors'])
#
# NameError: name 'df_missing' is not defined

# %%
df_missing
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-2327262285> in <cell line: 0>()
# ----> 1 df_missing
#
# NameError: name 'df_missing' is not defined

# %%
# remove the missing values of column, Price
df_missing = df_missing.dropna(subset=['Price'])

# %%
df_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  toyota  White  150043.000000    4.0   $4,000
# 1   honda    Red   87899.000000    4.0   $5,000
# 2  toyota   Blue   92302.666667    3.0   $7,000
# 3     bmw  Black   11179.000000    5.0  $22,000
# 4  nissan  White  213095.000000    4.0   $3,500
# 5  toyota  Green   92302.666667    4.0   $4,500

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")
df_missing = pd.read_csv('https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales-missing-data.csv')

# %%
# Check out the new DataFrame
df_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill the Odometer column missing values with the mean of the column inplace
df_missing['Odometer'].fillna(value=df_missing['Odometer'].mean(), inplace=True)
# Out:
# <ipython-input-89-cec1c59d7835>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_missing['Odometer'].fillna(value=df_missing['Odometer'].mean(), inplace=True)
# <ipython-input-89-cec1c59d7835>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_missing['Odometer'].fillna(value=df_missing['Odometer'].mean(), inplace=True)

# %%
# View the car sales missing DataFrame and verify the changes
df_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue   98763.2    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green   98763.2    4.0   $4,500
# 6   Honda    NaN   98763.2    4.0   $7,500
# 7   Honda   Blue   98763.2    4.0      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Remove the rest of the missing data inplace
df_missing.dropna(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-2288005279> in <cell line: 0>()
#       1 # Remove the rest of the missing data inplace
# ----> 2 df_missing.dropna(inplace=True)
#
# NameError: name 'df_missing' is not defined

# %%
len(df['Make'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Make'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-3062813011> in <cell line: 0>()
# ----> 1 len(df['Make'])
#
# ...

# %%
# Verify the missing values are removed by viewing the DataFrame
df_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
# Create a "Seats" column where every row has a value of 5
df['Seats'] = 5

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame
df_missing['Price'] = df_missing['Price'].replace({'\$': '', ',': ''}, regex=True).astype(float)
df_missing['Price Per Odometer(KM)'] = df_missing['Price'] / df_missing['Odometer']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-2785940973> in <cell line: 0>()
#       1 # Create a column which represents the price of a car per kilometer
#       2 # Then view the DataFrame
# ----> 3 df_missing['Price'] = df_missing['Price'].replace({'\$': '', ',': ''}, regex=True).astype(float)
#       4 df_missing['Price Per Odometer(KM)'] = df_missing['Price'] / df_missing['Odometer']
#
# NameError: name 'df_missing' is not defined

# %%
# Remove the last column you added using .drop()
df_missing = df_missing.drop(columns=['Price Per Odometer(KM)'])

# %%
df.isna().sum()
# Out:
# Make                  0
# Colour                0
# Odometer (KM)         0
# Doors                 0
# Price                 0
# Odometer per Doors    0
# Seats                 0
# Engine Size           0
# dtype: int64

# %%
df.drop(['Make', 'Colour'], axis=1, inplace=True)

# %%
df
# Out:
#    Odometer (KM)  Doors       Price
# 0         150043      4   $4,000.00
# 1          87899      4   $5,000.00
# 2          32549      3   $7,000.00
# 3          11179      5  $22,000.00
# 4         213095      4   $3,500.00
# 5          99213      4   $4,500.00
# 6          45698      4   $7,500.00
# 7          54738      4   $7,000.00
# 8          60000      4   $6,250.00
# 9          31600      4   $9,700.00

# %%
df.columns
# Out:
# Index(['Odometer (KM)', 'Doors', 'Price', 'Odometer per Doors', 'Seats',
#        'Engine Size'],
#       dtype='object')

# %%
df['Price'].str.replace('$', ' ').str.replace('.', ' ').str.replace(',', ' ')
df
# Out:
#    Odometer (KM)  Doors  Price  Odometer per Doors  Seats  Engine Size
# 0         150043      4    0.4        37510.750000      5     3.125402
# 1          87899      4    0.5        21974.750000      5     3.776835
# 2          32549      3    0.7        10849.666667      5     2.258074
# 3          11179      5    2.2         2235.800000      5     3.071143
# 4         213095      4   0.35        53273.750000      5     3.589740
# 5          99213      4   0.45        24803.250000      5     2.953654
# 6          45698      4   0.75        11424.500000      5     1.415271
# 7          54738      4    0.7        13684.500000      5     3.178087
# 8          60000      4  0.625        15000.000000      5     3.131428
# 9          31600      4   0.97         7900.000000      5     2.297946

# %%
df_color_series = pd.Series(['White', 'Red', 'Blue'])
df_color_series
# Out:
# 0    White
# 1      Red
# 2     Blue
# dtype: object

# %%
df_car_series = pd.Series(['Toyota', 'Honda', 'BMW'])
df_car_series
# Out:
# 0    Toyota
# 1     Honda
# 2       BMW
# dtype: object

# %%
df_cars = pd.Series(['Toyota', 'Honda', 'BMW', 'Nissan'])
df_colours = pd.Series(['White', 'Red', 'Blue', 'Black', 'Green'])
combined_data = pd.concat([df_cars, df_colours], axis=1)
combined_data
# Out:
#         0      1
# 0  Toyota  White
# 1   Honda    Red
# 2     BMW   Blue
# 3  Nissan  Black
# 4     NaN  Green

# %%
df.dtypes
# Out:
# Odometer (KM)           int64
# Doors                   int64
# Price                  object
# Odometer per Doors    float64
# Seats                   int64
# Engine Size           float64
# dtype: object

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
mean_of_number_series = pd.Series([1, 2, 3, 4, 5, 6, 7, 8]).mean()
mean_of_number_series
# Out:
# np.float64(4.5)

# %%
# Create a "Seats" column where every row has a value of 5
df_missing['Seats'] = 5

# %%
# generate random values
get_random_values = np.random.randint(1.3, 4.5, size=len(df_missing))
df_missing['Engine Size'] = get_random_values

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
shuffled_df = df_missing.sample(frac=1)

# %%
shuffled_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 4  Nissan  White  213095.000000    4.0   3500.0      5            3
# 0  Toyota  White  150043.000000    4.0   4000.0      5            2
# 1   Honda    Red   87899.000000    4.0   5000.0      5            2
# 5  Toyota  Green   92302.666667    4.0   4500.0      5            3
# 2  Toyota   Blue   92302.666667    3.0   7000.0      5            1
# 3     BMW  Black   11179.000000    5.0  22000.0      5            3

# %%
shuffled_df.reset_index(drop=True, inplace=True)

# %%
shuffled_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Nissan  White  213095.000000    4.0   3500.0      5            3
# 1  Toyota  White  150043.000000    4.0   4000.0      5            2
# 2   Honda    Red   87899.000000    4.0   5000.0      5            2
# 3  Toyota  Green   92302.666667    4.0   4500.0      5            3
# 4  Toyota   Blue   92302.666667    3.0   7000.0      5            1
# 5     BMW  Black   11179.000000    5.0  22000.0      5            3

# %%
df_missing['Odometer'] = df_missing['Odometer'].apply(lambda km: km * 0.621371)

# %%
df_missing.rename(columns={'Odemeter': 'Odometer (Miles)'}, inplace=True)

# %%
df_missing
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White   93232.368953    4.0   4000.0      5            2
# 1   Honda    Red   54617.889529    4.0   5000.0      5            2
# 2  Toyota   Blue   57354.200289    3.0   7000.0      5            1
# 3     BMW  Black    6946.306409    5.0  22000.0      5            3
# 4  Nissan  White  132411.053245    4.0   3500.0      5            3
# 5  Toyota  Green   57354.200289    4.0   4500.0      5            3

# %%
animals = pd.Series(['dog', 'bear', 'lion', 'swan', 'hawk'])
print(animals)
# Out:
# 0     dog
# 1    bear
# 2    lion
# 3    swan
# 4    hawk
# dtype: object

# %%
df = pd.DataFrame({'Animal': colors})
df['Animal Length'] = df['Animal'].apply(len)
print(df)
# Out:
#   Animal  Animal Length
# 0    red              3
# 1  green              5
# 2   blue              4

# %%
df['Animal'].value_counts()
# Out:
# Animal
# red      1
# green    1
# blue     1
# Name: count, dtype: int64

# %%
df.groupby('Animal').mean()
# Out:
#         Animal Length
# Animal
# blue              4.0
# green             5.0
# red               3.0

# %%
df.drop(0)
# Out:
#   Animal  Animal Length
# 1  green              5
# 2   blue              4

# %%
# !wget https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Out:
# --2025-05-06 13:30:59--  https://raw.githubusercontent.com/Rstam59/TaskDataRepoForStudents/refs/heads/main/car-sales.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 369 [text/plain]
# Saving to: ‘car-sales.csv.1’
#
# car-sales.csv.1     100%[===================>]     369  --.-KB/s    in 0s
#
# 2025-05-06 13:30:59 (5.90 MB/s) - ‘car-sales.csv.1’ saved [369/369]

# %%
df = pd.read_csv('/content/car-sales.csv')

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
df.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#           index  Odometer (KM)      Doors
# count  10.00000      10.000000  10.000000
# mean    4.50000   78601.400000   4.000000
# std     3.02765   61983.471735   0.471405
# min     0.00000   11179.000000   3.000000
# 25%     2.25000   35836.250000   4.000000
# 50%     4.50000   57369.000000   4.000000
# 75%     6.75000   96384.500000   4.000000
# max     9.00000  213095.000000   5.000000

# %%
df.columns
# Out:
# Index(['index', 'Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
df.set_index('Make',inplace=True)

# %%
df[['Odometer (KM)', 'Price']]
# Out:
#    Odometer (KM)       Price
# 0         150043   $4,000.00
# 1          87899   $5,000.00
# 2          32549   $7,000.00
# 3          11179  $22,000.00
# 4         213095   $3,500.00
# 5          99213   $4,500.00
# 6          45698   $7,500.00
# 7          54738   $7,000.00
# 8          60000   $6,250.00
# 9          31600   $9,700.00

# %%
toyotas = df.loc['Toyota']
toyotas
# Out:
#         index Colour  Odometer (KM)  Doors      Price
# Make
# Toyota      0  White         150043      4  $4,000.00
# Toyota      2   Blue          32549      3  $7,000.00
# Toyota      5  Green          99213      4  $4,500.00
# Toyota      8  White          60000      4  $6,250.00

# %%
toyotas.describe()
# Out:
#        index  Odometer (KM)  Doors
# count   4.00       4.000000   4.00
# mean    3.75   85451.250000   3.75
# std     3.50   51015.991325   0.50
# min     0.00   32549.000000   3.00
# 25%     1.50   53137.250000   3.75
# 50%     3.50   79606.500000   4.00
# 75%     5.75  111920.500000   4.00
# max     8.00  150043.000000   4.00

# %%
df.iloc[4]
# Out:
# index                    4
# Make                Nissan
# Colour               White
# Odometer (KM)       213095
# Doors                    4
# Price            $3,500.00
# Name: 4, dtype: object

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.columns.tolist()
# Out:
# ['index', 'Colour', 'Odometer (KM)', 'Doors', 'Price']

# %%
df['Price'] = df['Price'].str.replace('$', '').str.replace(',','')

# %%
df['Price'] = pd.to_numeric(df['Price'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Toyota to Nissan
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          10 non-null     int64
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 780.0+ bytes

# %%
sum(df.Price)
# Out:
# 76450.0

# %%
df.isna().sum()
# Out:
# index            0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
np.nan
# Out:
# nan

# %%
df['Price_with_nans'] = [4000.0,
 5000.0,
 np.nan,
 22000.0,
 3500.0,
 np.nan,
 7500.0,
 7000.0,
 np.nan,
 9700.0]

# %%
df
# Out:
#         index Colour  Odometer (KM)  Doors    Price  Price_with_nans
# Make
# Toyota      0  White         150043      4   4000.0           4000.0
# Honda       1    Red          87899      4   5000.0           5000.0
# Toyota      2   Blue          32549      3   7000.0              NaN
# BMW         3  Black          11179      5  22000.0          22000.0
# Nissan      4  White         213095      4   3500.0           3500.0
# Toyota      5  Green          99213      4   4500.0              NaN
# Honda       6   Blue          45698      4   7500.0           7500.0
# Honda       7   Blue          54738      4   7000.0           7000.0
# Toyota      8  White          60000      4   6250.0              NaN
# Nissan      9  White          31600      4   9700.0           9700.0

# %%
df.isna().sum()   # isnull
# Out:
# index              0
# Colour             0
# Odometer (KM)      0
# Doors              0
# Price              0
# Price_with_nans    3
# dtype: int64

# %%
df.notna().sum()   # notnull
# Out:
# index              10
# Colour             10
# Odometer (KM)      10
# Doors              10
# Price              10
# Price_with_nans     7
# dtype: int64

# %%
df.drop(['Price_with_nans'], axis=1, inplace=True)

# %%
df
# Out:
#         index Colour  Odometer (KM)  Doors    Price
# Make
# Toyota      0  White         150043      4   4000.0
# Honda       1    Red          87899      4   5000.0
# Toyota      2   Blue          32549      3   7000.0
# BMW         3  Black          11179      5  22000.0
# Nissan      4  White         213095      4   3500.0
# Toyota      5  Green          99213      4   4500.0
# Honda       6   Blue          45698      4   7500.0
# Honda       7   Blue          54738      4   7000.0
# Toyota      8  White          60000      4   6250.0
# Nissan      9  White          31600      4   9700.0

# %%
nums = pd.Series([1, 2, 3])
colors = pd.Series(['White', 'Black', 'REd'])

# %%
nums
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
df1 = pd.DataFrame(nums, columns=['nums'])

# %%
df1
# Out:
#    nums
# 0     1
# 1     2
# 2     3

# %%
df1['colors'] = colors

# %%
df1
# Out:
#    nums colors
# 0     1  White
# 1     2  Black
# 2     3    REd

# %%
dict1 = {
    'names': ['Raul', 'Asim', 'Aida', 'Aide'],
    'scores': [100, 96, 87, 89]
}

# %%
dict1
# Out:
# {'names': ['Raul', 'Asim', 'Aida', 'Aide'], 'scores': [100, 96, 87, 89]}

# %%
pd.DataFrame(dict1)
# Out:
#   names  scores
# 0  Raul     100
# 1  Asim      96
# 2  Aida      87
# 3  Aide      89

# %%
df.Price.sum()
# Out:
# np.float64(76450.0)

# %%
df.Price.mean()
# Out:
# np.float64(7645.0)

# %%
df.Price.min()
# Out:
# 3500.0

# %%
df.Price.max()
# Out:
# 22000.0

# %%
df.Price.std()
# Out:
# 5379.407753440687

# %%
df.Price.mode()
# Out:
# 0    7000.0
# Name: Price, dtype: float64

# %%
df['odometer_per_door'] = df['Odometer (KM)'] / df['Doors']

# %%
150043 / 4
# Out:
# 37510.75

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'index'}>,
#         <Axes: title={'center': 'Odometer (KM)'}>],
#        [<Axes: title={'center': 'Doors'}>,
#         <Axes: title={'center': 'Price'}>],
#        [<Axes: title={'center': 'odometer_per_door'}>, <Axes: >]],
#       dtype=object)

# %%
df['Price'].hist()
# Out:
# <Axes: >

# %%
df.Colour.value_counts()
# Out:
# Colour
# White    4
# Blue     3
# Red      1
# Black    1
# Green    1
# Name: count, dtype: int64

# %%
df.Colour.nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-dbcb9be6815c> in <cell line: 0>()
# ----> 1 df.Colour.nunique()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Colour'

# %%
df.Colour.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-002e7dd1903e> in <cell line: 0>()
# ----> 1 df.Colour.unique()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'Colour'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nijatjafarov/YouTubeProjects/refs/heads/main/Pandas/%232/turbo.csv')
df
# Out:
#           Price  Year Engine    Distance
# 0    12 700 AZN  2008  1.5 L  384 633 km
# 1    19 000 AZN  2010  1.8 L  316 656 km
# 2    13 900 AZN  2008  1.5 L  175 000 km
# 3    12 800 AZN  2007  1.5 L  210 000 km
# 4    14 500 AZN  2006  1.5 L  137 000 km
# ..          ...   ...    ...         ...
# 987  19 000 AZN  2012  1.8 L  167 000 km
# 988  10 000 AZN  2007  1.5 L  187 000 km
# 989  20 000 AZN  2007  1.5 L  150 000 km
# 990  13 900 AZN  2008  1.5 L  175 000 km
# 991  12 200 AZN  2008  1.5 L  150 000 km
#
# [992 rows x 4 columns]

# %%
pd.options.display.max_columns
# Out:
# 20

# %%
df.head(170)
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Odometer per Doors
# 0  toyota  White         150043      4    0.4        37510.750000
# 1   honda    Red          87899      4    0.5        21974.750000
# 2  toyota   Blue          32549      3    0.7        10849.666667
# 3     bmw  Black          11179      5    2.2         2235.800000
# 4  nissan  White         213095      4   0.35        53273.750000
# 5  toyota  Green          99213      4   0.45        24803.250000
# 6   honda   Blue          45698      4   0.75        11424.500000
# 7   honda   Blue          54738      4    0.7        13684.500000
# 8  toyota  White          60000      4  0.625        15000.000000
# 9  nissan  White          31600      4   0.97         7900.000000

# %%
şagirdlər = {
    'Ad': ['Kamil', 'Şəhla', 'Arzu'],
    'Soyad': ['Orucov', 'Qasımova', 'Teymurova'],
    'Qiymət': [87, 93, 75]
}

# %%
df = pd.DataFrame(şagirdlər)
df
# Out:
#       Ad      Soyad  Qiymət
# 0  Kamil     Orucov      87
# 1  Şəhla   Qasımova      93
# 2   Arzu  Teymurova      75

# %%
df['Soyad']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Soyad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-96-a06a99a61bba> in <cell line: 0>()
# ----> 1 df['Soyad']
#
# ...

# %%
type(df['Soyad'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Soyad'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-f11f4a8c60bc> in <cell line: 0>()
# ----> 1 type(df['Soyad'])
#
# ...

# %%
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price',
#        'Odometer per Doors'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'Make'

# %%
df[['Ad', 'Soyad']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-93-14b8e77bf32b> in <cell line: 0>()
# ----> 1 df[['Ad', 'Soyad']]
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
df.iloc[1]
# Out:
# Make                     honda
# Colour                     Red
# Odometer (KM)            87899
# Doors                        4
# Price                      0.5
# Odometer per Doors    21974.75
# Name: 1, dtype: object

# %%
df.iloc[[0, 2]]
# Out:
#       Ad      Soyad  Qiymət
# 0  Kamil     Orucov      87
# 2   Arzu  Teymurova      75

# %%
df.iloc[[0, 2], 1]
# Out:
# 0       Orucov
# 2    Teymurova
# Name: Soyad, dtype: object

# %%
df.iloc[[0, 2], [0, 2]]
# Out:
#       Ad  Qiymət
# 0  Kamil      87
# 2   Arzu      75

# %%
turbo_df = pd.read_csv('https://raw.githubusercontent.com/nijatjafarov/YouTubeProjects/refs/heads/main/Pandas/%232/turbo.csv')
turbo_df
# Out:
#           Price  Year Engine    Distance
# 0    12 700 AZN  2008  1.5 L  384 633 km
# 1    19 000 AZN  2010  1.8 L  316 656 km
# 2    13 900 AZN  2008  1.5 L  175 000 km
# 3    12 800 AZN  2007  1.5 L  210 000 km
# 4    14 500 AZN  2006  1.5 L  137 000 km
# ..          ...   ...    ...         ...
# 987  19 000 AZN  2012  1.8 L  167 000 km
# 988  10 000 AZN  2007  1.5 L  187 000 km
# 989  20 000 AZN  2007  1.5 L  150 000 km
# 990  13 900 AZN  2008  1.5 L  175 000 km
# 991  12 200 AZN  2008  1.5 L  150 000 km
#
# [992 rows x 4 columns]

# %%
turbo_df.iloc[250:370, 0:2]
# Out:
#           Price  Year
# 250  17 600 AZN  2011
# 251  13 750 AZN  2007
# 252  22 300 AZN  2013
# 253  19 400 AZN  2014
# 254  10 000 AZN  2008
# 255  13 100 AZN  2008
# 256  22 300 AZN  2013
# 257  15 400 AZN  2010
# 258  19 900 AZN  2014
# 259  13 200 AZN  2007
# 260  16 500 AZN  2010
# 261  13 750 AZN  2008
# 262  10 000 AZN  2007
# 263  12 900 AZN  2006
# 264  12 500 AZN  2007
# 265  12 500 AZN  2007
# 266  13 600 AZN  2008
# 267  13 700 AZN  2007
# 268  11 900 AZN  2008
# 269  15 000 AZN  2007
# 270  13 200 AZN  2008
# 271  13 200 AZN  2008
# 272  14 400 AZN  2008
# 273  11 500 AZN  2006
# 274  13 500 AZN  2007
# 275  16 100 AZN  2010
# 276  13 800 AZN  2008
# 277  13 700 AZN  2007
# 278  14 300 AZN  2006
# 279  12 900 AZN  2007
# 280  13 500 AZN  2008
# 281  16 800 AZN  2009
# 282  13 900 AZN  2009
# 283  13 700 AZN  2008
# 284  16 100 AZN  2011
# 285  18 700 AZN  2012
# 286  19 900 AZN  2014
# 287  11 800 AZN  2006
# 288  16 500 AZN  2010
# 289  12 900 AZN  2008
# ...

# %%
turbo_df.loc[125]
# Out:
# Price       13 500 AZN
# Year              2006
# Engine           1.5 L
# Distance    132 930 km
# Name: 125, dtype: object

# %%
turbo_df.loc[110:245, 'Price':'Engine']
# Out:
#           Price  Year Engine
# 110  12 900 AZN  2007  1.5 L
# 111  12 950 AZN  2005  1.5 L
# 112  12 950 AZN  2008  1.5 L
# 113  15 900 AZN  2010  1.8 L
# 114  17 300 AZN  2010  1.8 L
# ..          ...   ...    ...
# 241  13 700 AZN  2007  1.5 L
# 242  11 900 AZN  2008  1.5 L
# 243  20 900 AZN  2012  1.8 L
# 244  13 500 AZN  2007  1.5 L
# 245  12 900 AZN  2007  1.5 L
#
# [136 rows x 3 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nijatjafarov/YouTubeProjects/refs/heads/main/Pandas/%233/data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.loc[245]
# Out:
# title     Why are stolen African artifacts still in West...
# author                                           Jim Chuchu
# date                                              July 2021
# views                                               1600000
# likes                                                 48000
# link      https://ted.com/talks/jim_chuchu_why_are_stole...
# Name: 245, dtype: object

# %%
df2 = df.set_index('link')
df2
# Out:
#                                                                                                 title  \
# link
# https://ted.com/talks/ozawa_bineshi_albert_clim...      Climate action needs new frontline leadership
# https://ted.com/talks/sydney_iaukea_the_dark_hi...        The dark history of the overthrow of Hawaii
# https://ted.com/talks/martin_reeves_how_play_ca...     How play can spark new ideas for your business
# https://ted.com/talks/james_k_thornton_why_is_c...  Why is China appointing judges to combat clima...
# https://ted.com/talks/mahendra_singhi_cement_s_...     Cement's carbon problem — and 2 ways to fix it
# ...                                                                                               ...
# https://ted.com/talks/hans_rosling_the_best_sta...                    The best stats you've ever seen
# https://ted.com/talks/sir_ken_robinson_do_schoo...                        Do schools kill creativity?
# ...

# %%
df.set_index('link', inplace=True)
df
# Out:
#                                                                                                 title  \
# link
# https://ted.com/talks/ozawa_bineshi_albert_clim...      Climate action needs new frontline leadership
# https://ted.com/talks/sydney_iaukea_the_dark_hi...        The dark history of the overthrow of Hawaii
# https://ted.com/talks/martin_reeves_how_play_ca...     How play can spark new ideas for your business
# https://ted.com/talks/james_k_thornton_why_is_c...  Why is China appointing judges to combat clima...
# https://ted.com/talks/mahendra_singhi_cement_s_...     Cement's carbon problem — and 2 ways to fix it
# ...                                                                                               ...
# https://ted.com/talks/hans_rosling_the_best_sta...                    The best stats you've ever seen
# https://ted.com/talks/sir_ken_robinson_do_schoo...                        Do schools kill creativity?
# ...

# %%
df.iloc[5]
# Out:
# title     The tragedy of air pollution — and an urgent d...
# author                           Rosamund Adoo-Kissi-Debrah
# date                                           October 2021
# views                                                422000
# likes                                                 12000
# Name: https://ted.com/talks/rosamund_adoo_kissi_debrah_the_tragedy_of_air_pollution_and_an_urgent_demand_for_clean_air, dtype: object

# %%
df.loc['https://ted.com/talks/martin_reeves_how_play_can_spark_new_ideas_for_your_business', 'date']
# Out:
# 'September 2021'

# %%
df3 = df.reset_index()
df3
# Out:
#                                                    link  \
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#                                                    link  \
# 0     https://ted.com/talks/ozawa_bineshi_albert_cli...
# 1     https://ted.com/talks/sydney_iaukea_the_dark_h...
# 2     https://ted.com/talks/martin_reeves_how_play_c...
# 3     https://ted.com/talks/james_k_thornton_why_is_...
# 4     https://ted.com/talks/mahendra_singhi_cement_s...
# ...                                                 ...
# 5435  https://ted.com/talks/hans_rosling_the_best_st...
# 5436  https://ted.com/talks/sir_ken_robinson_do_scho...
# 5437  https://ted.com/talks/majora_carter_greening_t...
# 5438  https://ted.com/talks/david_pogue_simplicity_s...
# 5439  https://ted.com/talks/al_gore_averting_the_cli...
#
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nijatjafarov/YouTubeProjects/refs/heads/main/Pandas/%234/data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df['views'] > 400000
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 5435     True
# 5436     True
# 5437     True
# 5438     True
# 5439     True
# Name: views, Length: 5440, dtype: bool

# %%
df[df['views'] > 400000]
# Out:
#                                                   title  \
# 0         Climate action needs new frontline leadership
# 2        How play can spark new ideas for your business
# 3     Why is China appointing judges to combat clima...
# 5     The tragedy of air pollution — and an urgent d...
# 6                        The myth of Narcissus and Echo
# ...                                                 ...
# 5435                    The best stats you've ever seen
# 5436                        Do schools kill creativity?
# 5437                                Greening the ghetto
# 5438                                   Simplicity sells
# 5439                        Averting the climate crisis
#
#                           author            date     views    likes  \
# 0           Ozawa Bineshi Albert   December 2021    404000    12000
# 2                  Martin Reeves  September 2021    412000    12000
# 3              James K. Thornton    October 2021    427000    12000
# ...

# %%
filtr = (df['views'] > 400000) & (df['likes'] > 20000)

# %%
df[~filtr]
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5404               Why we should invest in a free press          Sasa Vucinic
# 5406                How mobile phones can fight poverty          Iqbal Quadir
# 5418            Meet the founder of the blog revolution            Mena Trott
# 5427                               One Laptop per Child   Nicholas Negroponte
# 5429                      My wish: A global day of film        Jehane Noujaim
#
# ...

# %%
df.loc[filtr, ['title', 'author']]
# Out:
#                                                   title              author
# 30                    The mind-bending art of deep time      Katie Paterson
# 32     A different understanding of American patriotism       Deval Patrick
# 35                  Which animal has the best eyesight?    Thomas W. Cronin
# 37    Are brain waves the secret to treating Alzheim...        Li-Huei Tsai
# 38      What if women built the world they want to see?  Emily Pilloton-Lam
# ...                                                 ...                 ...
# 5435                    The best stats you've ever seen        Hans Rosling
# 5436                        Do schools kill creativity?    Sir Ken Robinson
# 5437                                Greening the ghetto       Majora Carter
# 5438                                   Simplicity sells         David Pogue
# 5439                        Averting the climate crisis             Al Gore
#
# [4040 rows x 2 columns]

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nijatjafarov/YouTubeProjects/refs/heads/main/Pandas/%235/data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.columns = ['Title', 'Author', 'Date', 'Views', 'Likes', 'Link']
df
# Out:
#                                                   Title                Author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.columns = df.columns.str.replace('e', 'E')

# %%
df.columns = df.columns.str.replace('e', 'E')
df
# Out:
#                                                   TitlE                Author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.rename(columns = {'TitlE': 'Başlıq', 'LikEs': 'Bəyənmələr'})
# Out:
#                                                  Başlıq                Author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.loc[0] = ['Test title', 'Test Author', 'January 2020', 250000, 25000, 'Test URL']

# %%
df.loc[1, ['Author', 'ViEws']]
# Out:
# Author    Sydney Iaukea
# ViEws            214000
# Name: 1, dtype: object

# %%
df.loc[1, ['Author', 'ViEws']] = ['Tim Berners-Lee', 500000]
df
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test Author
# 1           The dark history of the overthrow of Hawaii    Tim Berners-Lee
# 2        How play can spark new ideas for your business      Martin Reeves
# 3     Why is China appointing judges to combat clima...  James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans Rosling
# 5436                        Do schools kill creativity?   Sir Ken Robinson
# 5437                                Greening the ghetto      Majora Carter
# 5438                                   Simplicity sells        David Pogue
# 5439                        Averting the climate crisis            Al Gore
#
#                 DatE     ViEws    LikEs  \
# ...

# %%
def artir(deyer):
    return deyer + 1

# %%
df = pd.read_csv('https://raw.githubusercontent.com/nijatjafarov/YouTubeProjects/refs/heads/main/Pandas/%236/data.csv')
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df['views'].apply(lambda x: x * 0.3)
# Out:
# 0         121200.0
# 1          64200.0
# 2         123600.0
# 3         128100.0
# 4            720.0
#            ...
# 5435     4500000.0
# 5436    21600000.0
# 5437      870000.0
# 5438      600000.0
# 5439     1080000.0
# Name: views, Length: 5440, dtype: float64

# %%
df['30%_views'] = df['views'].apply(lambda x: x * 0.3)
df
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.drop(columns = ['30%_views'])
# Out:
#                                                   title                author  \
# 0         Climate action needs new frontline leadership  Ozawa Bineshi Albert
# 1           The dark history of the overthrow of Hawaii         Sydney Iaukea
# 2        How play can spark new ideas for your business         Martin Reeves
# 3     Why is China appointing judges to combat clima...     James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it       Mahendra Singhi
# ...                                                 ...                   ...
# 5435                    The best stats you've ever seen          Hans Rosling
# 5436                        Do schools kill creativity?      Sir Ken Robinson
# 5437                                Greening the ghetto         Majora Carter
# 5438                                   Simplicity sells           David Pogue
# 5439                        Averting the climate crisis               Al Gore
#
# ...

# %%
df.sort_values(['ViEws', 'LikEs'], ascending=False)
# Out:
#                                                   TitlE  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4765                   How great leaders inspire action
# 4605                         The power of vulnerability
# ...                                                 ...
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 552                                      Virtual Worlds
# 613                  Post-Pandemic Paradise in Rapa Nui
# 3039                                 Year In Ideas 2015
#
#                                 Author            DatE     ViEws    LikEs  \
# 5436                  Sir Ken Robinson   February 2006  72000000  2100000
# 4084                         Amy Cuddy       June 2012  64000000  1900000
# ...

# %%
df.sort_values(['ViEws', 'LikEs'], ascending = [False, True], inplace = True)
df
# Out:
#                                                   TitlE  \
# 5436                        Do schools kill creativity?
# 4084           Your body language may shape who you are
# 2958         Inside the mind of a master procrastinator
# 4765                   How great leaders inspire action
# 4605                         The power of vulnerability
# ...                                                 ...
# 552                                      Virtual Worlds
# 1064  "Jamie Raeburn" / "Baloo Baleerie" / "Twa recr...
# 1692  "Part II. The Journey Through Time" / "Ruslan ...
# 613                  Post-Pandemic Paradise in Rapa Nui
# 3039                                 Year In Ideas 2015
#
#                                 Author            DatE     ViEws    LikEs  \
# 5436                  Sir Ken Robinson   February 2006  72000000  2100000
# 4084                         Amy Cuddy       June 2012  64000000  1900000
# ...

# %%
df.sort_index()
# Out:
#                                                   TitlE             Author  \
# 0                                            Test title        Test Author
# 1           The dark history of the overthrow of Hawaii    Tim Berners-Lee
# 2        How play can spark new ideas for your business      Martin Reeves
# 3     Why is China appointing judges to combat clima...  James K. Thornton
# 4        Cement's carbon problem — and 2 ways to fix it    Mahendra Singhi
# ...                                                 ...                ...
# 5435                    The best stats you've ever seen       Hans Rosling
# 5436                        Do schools kill creativity?   Sir Ken Robinson
# 5437                                Greening the ghetto      Majora Carter
# 5438                                   Simplicity sells        David Pogue
# 5439                        Averting the climate crisis            Al Gore
#
#                 DatE     ViEws    LikEs  \
# ...

# %%
df['Author'].sort_values()
# Out:
# 3069            B.E.A.T. NYC
# 736               Beautyrest
# 14       Belle and Sebastian
# 933             Butterscotch
# 1390        Climbing PoeTree
#                 ...
# 3983       iO Tillett Wright
# 193               monday.com
# 2083           tobacco brown
# 1800             Özlem Cekic
# 3039                     NaN
# Name: Author, Length: 5440, dtype: object

# %%
df['ViEws'].nlargest(7)
# Out:
# 5436    72000000
# 4084    64000000
# 2958    60000000
# 4765    57000000
# 4605    56000000
# 3504    49000000
# 2168    43000000
# Name: ViEws, dtype: int64
